# %%
import sys
# !{sys.executable} -m pip install matplotlib

# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in C:\Users\natha\miniconda3\Lib\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\natha\miniconda3\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\natha\miniconda3\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\natha\miniconda3\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\natha\miniconda3\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\natha\miniconda3\Lib\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in C:\Users\natha\miniconda3\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=9 in C:\Users\natha\miniconda3\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\natha\miniconda3\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\natha\miniconda3\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\natha\miniconda3\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
#Random Walk Simulator
import random
import matplotlib.pyplot as plt
random.seed(42)

# Function to simulate symmetric random walk with boundaries, starting at 0.
import numpy as np

def random_walk_vectorised(boundary, n_sims, max_steps=10000, seed=42):
    rng = np.random.default_rng(seed)
    steps = rng.choice([-1, 1], size=(n_sims, max_steps))
    positions = np.cumsum(steps, axis=1)

    # find first index where |position| >= boundary, for each simulation
    hit = np.abs(positions) >= boundary
    first_hit = np.argmax(hit, axis=1)  # first True index per row

    hitting_times = first_hit + 1
    final_positions = positions[np.arange(n_sims), first_hit]

    return hitting_times, final_positions

hitting_times, final_positions = random_walk_vectorised(10, 1000)
prob_positive = np.mean(final_positions == 10)
prob_negative = np.mean(final_positions == -10)

# Calculate & print hitting probabilities
prob_positive = hits_positive / 1000
prob_negative = hits_negative / 1000
print("Probability of hitting +10:", prob_positive)
print("Probability of hitting -10:", prob_negative)

# Plot distribution of hitting times
plt.hist(results, bins = 50)
plt.xlabel("Hitting Time")
plt.ylabel("Frequency")
plt.title("Random Walk Hitting Time Distribution")
plt.show()

# Random Walk - This section builds a basic Monte Carlo model using a symmetric random walk with absorbing boundaries at ±10.
#The aim is to estimate hitting probabilities and visualise the distribution of hitting times.
#The histogram shows a right-skewed distribution, which is typical for random walks with absorbing states.
#The empirical hitting probabilities are close to 0.5, matching the theoretical expectation for a symmetric walk starting at 0.
# Out:
# Probability of hitting +10: 50.03
# Probability of hitting -10: 49.97

# %%
#Gamblers Ruin Model
import random

start = 50
target = 100
ruin = 0
bet_size = 1
ruin_count = 0
success_count = 0

def gamblers_ruin(start, target)
    bankroll = start
    step = 0
    while ruin < bankroll < target:
        winloss = random.choice([-1, 1])
        bankroll += winloss
        step += 1
        
    return step, bankroll

results = []
target = 100
ruin = 0

for i in range (1000):
    steps, final_bankroll = gamblers_ruin(start, target)
    results.append(steps)

    if final_bankroll == ruin:
        ruin_count += 1
    else:
        success_count += 1
